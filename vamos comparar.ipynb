# %%
import pandas as pd

# %%
planilha1 = pd.read_excel('tabela_vendas.xlsx')
planilha2 = pd.read_excel('tabela_vendas_nova.xlsx')

# %%
planilha1
# Out:
#     ID_Venda        Data     Cliente    Produto  Quantidade  Preco_Unitario  \
# 0          1  2025-02-04  Cliente_17  Produto_7           7          316.57
# 1          2  2024-03-26   Cliente_9  Produto_2           6          441.61
# 2          3  2025-01-27   Cliente_6  Produto_4          10          249.06
# 3          4  2024-11-21   Cliente_6  Produto_1           6          316.31
# 4          5  2024-04-09  Cliente_10  Produto_4           9           91.09
# 5          6  2024-05-12  Cliente_13  Produto_1           9          340.65
# 6          7  2024-12-22  Cliente_17  Produto_6           4          191.33
# 7          8  2024-12-31  Cliente_19  Produto_3           8          202.47
# 8          9  2024-03-25   Cliente_5  Produto_6           6          200.81
# 9         10  2024-07-28  Cliente_15  Produto_4           4          477.36
# 10        11  2024-08-25  Cliente_15  Produto_3           3          295.93
# ...
